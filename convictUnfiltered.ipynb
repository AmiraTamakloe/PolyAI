# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("participants_dataset.csv")

print("INFO SUR LE SET")
df.info()
print("HEAD")
print(df.head(10))

print("the name of all collumns : ")
column_title = []
for col_name in df.columns: 
    column_title.append(col_name)

print(column_title) #impression titres colonnes
print("coucou")
# Out:
# INFO SUR LE SET
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 53 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       7214 non-null   int64
#  1   name                     7214 non-null   object
#  2   first                    7214 non-null   object
#  3   last                     7214 non-null   object
#  4   compas_screening_date    7214 non-null   object
#  5   sex                      7214 non-null   object
#  6   dob                      7214 non-null   object
#  7   age                      7214 non-null   int64
#  8   age_cat                  7214 non-null   object
#  9   race                     7214 non-null   object
#  10  juv_fel_count            7214 non-null   int64
#  11  decile_score             7214 non-null   int64
#  12  juv_misd_count           7214 non-null   int64
#  13  juv_other_count          7214 non-null   int64
#  14  priors_count             7214 non-null   int64
#  15  days_b_screening_arrest  6907 non-null   float64
#  16  c_jail_in                6907 non-null   object
#  17  c_jail_out               6907 non-null   object
#  18  c_case_number            7192 non-null   object
#  19  c_offense_date           6055 non-null   object
#  20  c_arrest_date            1137 non-null   object
#  21  c_days_from_compas       7192 non-null   float64
#  22  c_charge_degree          7214 non-null   object
#  23  c_charge_desc            7185 non-null   object
#  24  is_recid                 7214 non-null   int64
#  25  r_case_number            3471 non-null   object
#  26  r_charge_degree          3471 non-null   object
#  27  r_days_from_arrest       2316 non-null   float64
#  28  r_offense_date           3471 non-null   object
#  29  r_charge_desc            3413 non-null   object
#  30  r_jail_in                2316 non-null   object
#  31  r_jail_out               2316 non-null   object
#  32  violent_recid            0 non-null      float64
#  33  is_violent_recid         7214 non-null   int64
#  34  vr_case_number           819 non-null    object
#  35  vr_charge_degree         819 non-null    object
#  36  vr_offense_date          819 non-null    object
#  37  vr_charge_desc           819 non-null    object
#  38  type_of_assessment       7214 non-null   object
#  39  decile_score.1           7214 non-null   int64
#  40  score_text               7214 non-null   object
#  41  screening_date           7214 non-null   object
#  42  v_type_of_assessment     7214 non-null   object
#  43  v_decile_score           7214 non-null   int64
#  44  v_score_text             7214 non-null   object
#  45  v_screening_date         7214 non-null   object
#  46  in_custody               6978 non-null   object
#  47  out_custody              6978 non-null   object
#  48  priors_count.1           7214 non-null   int64
#  49  start                    7214 non-null   int64
#  50  end                      7214 non-null   int64
#  51  event                    7214 non-null   int64
#  52  label                    5771 non-null   float64
# dtypes: float64(5), int64(15), object(33)
# memory usage: 2.9+ MB
# HEAD
#      ID               name     first       last compas_screening_date     sex  \
# 0   452         steven lux    steven        lux            2013-01-05    Male
# 1   573        andre small     andre      small            2013-04-03    Male
# 2  4952        willie gray    willie       gray            2014-10-31    Male
# 3  3521  nickson marcellus   nickson  marcellus            2014-01-23    Male
# 4   369      patria barnes    patria     barnes            2013-12-09  Female
# 5  4436       david corbin     david     corbin            2013-11-12    Male
# 6  9085       joseph brock    joseph      brock            2013-03-26    Male
# 7  9776     domimick sarlo  domimick      sarlo            2013-10-22    Male
# 8  6485      tyrone dalton    tyrone     dalton            2013-03-27    Male
# 9  8683     carlos vasquez    carlos    vasquez            2013-03-01    Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1953-06-15   62  Greater than 45         Caucasian  ...               1
# 1  1987-10-01   28          25 - 45  African-American  ...               3
# 2  1959-01-12   57  Greater than 45  African-American  ...               2
# 3  1996-07-11   19     Less than 25  African-American  ...              10
# 4  1978-06-06   37          25 - 45             Other  ...               1
# 5  1993-02-18   23     Less than 25  African-American  ...               9
# 6  1989-10-20   26          25 - 45         Caucasian  ...               4
# 7  1952-08-10   63  Greater than 45         Caucasian  ...               1
# 8  1959-07-30   56  Greater than 45  African-American  ...               1
# 9  1985-05-16   30          25 - 45         Caucasian  ...               3
#
#    v_score_text  v_screening_date  in_custody  out_custody  priors_count.1  \
# 0           Low        2013-01-05  2014-03-25   2014-03-26               0
# 1           Low        2013-04-03  2013-04-02   2013-04-04               1
# 2           Low        2014-10-31  2014-10-31   2014-10-31               8
# 3          High        2014-01-23  2016-01-05   2016-02-26               1
# 4           Low        2013-12-09  2013-12-08   2013-12-09               0
# 5          High        2013-11-12  2014-01-24   2014-01-26               4
# 6           Low        2013-03-26  2013-03-25   2013-03-26               2
# 7           Low        2013-10-22         NaN          NaN               1
# 8           Low        2013-03-27  2013-03-26   2013-04-02               0
# 9           Low        2013-03-01  2013-02-07   2013-02-07               2
#
#   start   end event label
# 0     2   444     0   0.0
# 1     1  1094     0   0.0
# 2     0   265     1   1.0
# 3     0   711     1   1.0
# 4     0   844     0   0.0
# 5     0    73     1   1.0
# 6     0  1102     0   0.0
# 7     0   892     0   0.0
# 8     6  1101     0   0.0
# 9     0  1127     0   0.0
#
# [10 rows x 53 columns]
# the name of all collumns :
# ['ID', 'name', 'first', 'last', 'compas_screening_date', 'sex', 'dob', 'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count', 'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number', 'c_offense_date', 'c_arrest_date', 'c_days_from_compas', 'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number', 'r_charge_degree', 'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid', 'is_violent_recid', 'vr_case_number', 'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc', 'type_of_assessment', 'decile_score.1', 'score_text', 'screening_date', 'v_type_of_assessment', 'v_decile_score', 'v_score_text', 'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1', 'start', 'end', 'event', 'label']

# %%
df.ID = pd.Categorical(df.ID)
df['ID_code'] = df.ID.cat.codes
df.name = pd.Categorical(df.name)
df['name_code'] = df.name.cat.codes
df.first = pd.Categorical(df.first)
df['first_code'] = df.first.cat.codes
df.last = pd.Categorical(df.last)
df['last_code'] = df.last.cat.codes
df.compas_screening_date = pd.Categorical(df.compas_screening_date)
df['compas_screening_date_code'] = df.compas_screening_date.cat.codes
df.sex = pd.Categorical(df.sex)
df['sex_code'] = df.sex.cat.codes
df.dob = pd.Categorical(df.dob)
df['dob_code'] = df.dob.cat.codes
df.age = pd.Categorical(df.age)
df['age_code'] = df.age.cat.codes
df.age_cat = pd.Categorical(df.age_cat)
df['age_cat_code'] = df.age_cat.cat.codes
df.race = pd.Categorical(df.race)
df['race_code'] = df.race.cat.codes
df.juv_fel_count = pd.Categorical(df.juv_fel_count)
df['juv_fel_count_code'] = df.juv_fel_count.cat.codes
df.decile_score = pd.Categorical(df.decile_score)
df['decile_score_code'] = df.decile_score.cat.codes
df.juv_misd_count = pd.Categorical(df.juv_misd_count)
df['juv_misd_count_code'] = df.juv_misd_count.cat.codes
df.juv_other_count = pd.Categorical(df.juv_other_count)
df['juv_other_count_code'] = df.juv_other_count.cat.codes
df.priors_count = pd.Categorical(df.priors_count)
df['priors_count_code'] = df.priors_count.cat.codes
df.days_b_screening_arrest = pd.Categorical(df.days_b_screening_arrest)
df['days_b_screening_arrest_code'] = df.days_b_screening_arrest.cat.codes
df.c_jail_in = pd.Categorical(df.c_jail_in)
df['c_jail_in_code'] = df.c_jail_in.cat.codes
df.c_jail_out = pd.Categorical(df.c_jail_out)
df['c_jail_out_code'] = df.c_jail_out.cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
df. = pd.Categorical(df.)
df['_code'] = df..cat.codes
# Out:
#   File "C:\Users\Rapha\AppData\Local\Temp/ipykernel_27432/1898521207.py", line 37
#     df. = pd.Categorical(df.)
#         ^
# SyntaxError: invalid syntax

# %%
features = []
for element in column_title:
    features.append(element+"_code")

print(features)
# Out:
# ['ID_code', 'name_code', 'first_code', 'last_code', 'compas_screening_date_code', 'sex_code', 'dob_code', 'age_code', 'age_cat_code', 'race_code', 'juv_fel_count_code', 'decile_score_code', 'juv_misd_count_code', 'juv_other_count_code', 'priors_count_code', 'days_b_screening_arrest_code', 'c_jail_in_code', 'c_jail_out_code', 'c_case_number_code', 'c_offense_date_code', 'c_arrest_date_code', 'c_days_from_compas_code', 'c_charge_degree_code', 'c_charge_desc_code', 'is_recid_code', 'r_case_number_code', 'r_charge_degree_code', 'r_days_from_arrest_code', 'r_offense_date_code', 'r_charge_desc_code', 'r_jail_in_code', 'r_jail_out_code', 'violent_recid_code', 'is_violent_recid_code', 'vr_case_number_code', 'vr_charge_degree_code', 'vr_offense_date_code', 'vr_charge_desc_code', 'type_of_assessment_code', 'decile_score.1_code', 'score_text_code', 'screening_date_code', 'v_type_of_assessment_code', 'v_decile_score_code', 'v_score_text_code', 'v_screening_date_code', 'in_custody_code', 'out_custody_code', 'priors_count.1_code', 'start_code', 'end_code', 'event_code', 'label_code']
